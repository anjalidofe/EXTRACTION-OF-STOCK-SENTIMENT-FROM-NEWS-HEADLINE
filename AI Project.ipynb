# %%
# AI PROJECT
# TY Comp Div2

# Extraction of Stock Sentiment From News Headline

# Anjali Ajay Dofe (111903137)
# Aditya Rajesh Verma (111903134)


# We used our own audio files and did webscraping from finviz.com to get latest data and did not use pre existing data

# %%
# bs4 is a Python library for pulling data out of HTML files.
# news html files taken from Finviz.com
from bs4 import BeautifulSoup
import os

htmlTables = {}
'''BeautifulSoup is a class. 
 creating an object html.
 object.find() function we are using to find news table
 and adding that to our htmlTables dictionary'''


for table_name in os.listdir('Datasets_byMe'):
    #path to our dataset
    table_path = f'Datasets_byMe/{table_name}'
    #opening in read only mode
    table_file = open(table_path, 'r')
    # reading contents into html
    html = BeautifulSoup(table_file)
    # finding news-table in 'html_table'
    html_table = html.find(id='news-table')
   
    htmlTables[table_name] = html_table

# count = 0
#printing name and content of news-tables saved in htmlTables
for i, j in htmlTables.items():
    #checking out just one html file and filename
#     if count == 1:
#         break
#    print(f"{i}\n\n{j}")
    print(i)
    print("\n\n")
    #count +=1
    if i == "tsla_oct2021.html":
        print(f"{j}\n\n\n")
# Out:
# fb_oct2021.html
#
#
#
# hdb_oct2021.html
#
#
#
# infy_oct2021.html
#
#
#
# tsla_oct2021.html
#
#
#
# <table border="0" cellpadding="1" cellspacing="0" class="fullview-news-outer" id="news-table" width="100%">
# <tr><td align="right" style="white-space:nowrap" width="130">Nov-11-21 04:02AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/elon-musk-sells-tesla-shares-51636621314?siteid=yhoof2" target="_blank">Elon Musk Sells $5 Billion Worth of Tesla Shares. The Stock Is Rising.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">02:23AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/tesla-shares-rise-frankfurt-musks-072342405.html" target="_blank">Tesla shares rise in Frankfurt after Musk's $5 billion stock sale</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">01:09AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/elon-musk-sells-tesla-stock-234221907.html" target="_blank">Elon Musk Sells $5 Billion of Tesla Stock After Twitter Poll</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">12:07AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/a-made-in-america-tax-credit-what-car-buyers-considering-a-tesla-rivian-or-other-evs-need-to-know-about-build-back-better-11636581381?siteid=yhoof2" target="_blank">A Made in America tax credit  what car buyers considering a Tesla, Rivian or other EVs need to know about Build Back Better</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" style="white-space:nowrap" width="130">Nov-10-21 11:44PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.wsj.com/articles/elon-musk-sells-1-1-billion-in-tesla-stock-11636589559?mod=itp_wsj" target="_blank">Elon Musk Sells Around $5 Billion in Tesla Stock</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> The Wall Street Journal</span></div></div></td></tr>
# <tr><td align="right" width="130">10:56PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/elon-musk-sells-tesla-stock-in-plan-set-before-twitter-poll-sec-filing-shows-11636591389?siteid=yhoof2" target="_blank">Elon Musk has sold roughly $5 billion in Tesla stock this week, and probably isnt done</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" width="130">10:23PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/world-past-tipping-point-renewable-032326753.html" target="_blank">World past tipping point of renewable energy transformation, says Tesla's Denholm</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">09:57PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-market-rally-slumps-rivian-ipo-debut-tesla-bounce-affirm-spikes-disney-falls/?src=A00220" target="_blank">Dow Jones Futures: Market Rally Skids Despite Solid Rivian Debut; Tesla Discloses Musk Sale, Affirm Spikes</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">09:43PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/world-past-tipping-point-renewable-024353580.html" target="_blank">World past tipping point of renewable energy transformation, says Tesla's Denholm</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">08:10PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/elon-musk-sold-tesla-stock-it-wasnt-because-of-taxes-51636593001?siteid=yhoof2" target="_blank">Elon Musk Sold Tesla Stock. It Wasnt Because of Taxes.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">07:36PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/elon-musk-sells-1-1-003654970.html" target="_blank">Elon Musk sells $1.1 billion worth of Tesla shares</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> The Telegraph</span></div></div></td></tr>
# <tr><td align="right" width="130">07:33PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/rivian-ipo-officially-one-biggest-003312450.html" target="_blank">Rivian IPO Officially One of the Biggest Debuts of 2021</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
# <tr><td align="right" width="130">06:53PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/teslas-musk-sells-shares-ev-235320635.html" target="_blank">Tesla's Musk sells some shares of EV maker, filings show</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">06:51PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/tesla-driver-killed-in-fiery-crash-was-going-90-mph-ntsb-report-says-01636588260?siteid=yhoof2" target="_blank">Tesla driver killed in fiery crash was going 90 mph, NTSB report says</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" width="130">06:00PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/etfs-trouble-tesla-takes-hit-230011633.html" target="_blank">ETFs in Trouble as Tesla Takes the Hit of Musk's Twitter Poll</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
# <tr><td align="right" width="130">05:36PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/rivian-trading-debut-surge-drives-223623052.html" target="_blank">Rivians Trading Debut Surge Drives Value to Almost $88 Billion</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">04:58PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/rivian-founder-due-14-billion-130138345.html" target="_blank">Rivian Founder In For $14 Billion Windfall If Stock Triples</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">04:53PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/tesla-stock-elon-musk-sale-51636566643?siteid=yhoof2" target="_blank">Elon Musks Latest Tesla Stock Drama Is Almost Over. Now Fundamentals Can Take Over.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">04:35PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/stock-futures-fall-ahead-of-cpi-update-and-after-china-inflation-surges-11636539617?siteid=yhoof2" target="_blank">Dow ends 240 points lower as inflation surge sends Treasury yields sharply higher</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" width="130">04:34PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/us-stocks-wall-street-ends-213425558.html" target="_blank">US STOCKS-Wall Street ends lower as economic data raises long-term inflation threat</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">04:25PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/news/lucid-stock-poised-double-lcid-shares-edge-tesla-analyst-says-branch/?src=A00220" target="_blank">Tesla Rival Lucid Gets Big PT Hike But LCID Stock Dives As Rivian Debuts</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">04:19PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/arks-wood-not-appearing-buy-211931117.html" target="_blank">ARK'S Wood not appearing to buy the dip in Tesla shares</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">04:11PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/tesla-shares-fall-fourth-day-122541946.html" target="_blank">Tesla Rebounds After Almost Losing $1 Trillion-Club Membership</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">04:07PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/news/nio-stock-tests-early-entry-with-tesla-rivals-earnings-on-tap/?src=A00220" target="_blank">Nio Falls As Earnings Beat But Tesla Rival's Revenue Outlook Falls Short</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">04:07PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/rivian-likely-see-lot-volatility-210731357.html" target="_blank">Rivian likely to see a lot of volatility in the coming weeks: Analyst</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">04:05PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/news/rivian-ipo-rivn-on-tap-as-ev-startup-seeks-to-cash-in-with-tesla-lucid-soaring/?src=A00220" target="_blank">Rivian Soars In IPO Debut As It Cashes In On EV Stock Boom</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">04:01PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/us-stocks-wall-street-closes-210113176.html" target="_blank">US STOCKS-Wall Street closes lower as economic data raises long-term inflation threat</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">03:45PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/1-tesla-traveling-high-speed-204518310.html" target="_blank">UPDATE 1-Tesla was traveling at high speed before fatal Florida crash -NTSB</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">02:15PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/stocks-focus-rivian-tesla-luminar-191524430.html" target="_blank">Stocks in focus: Rivian, Tesla, Luminar, Coinbase, Booking</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">02:15PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/research/lucid-motors-stock-buy-now/?src=A00220" target="_blank">Is Lucid Motors Stock A Buy Right As Initial Deliveries Of Lucid Air Start?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">02:08PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/us-stocks-wall-street-extends-190823924.html" target="_blank">US STOCKS-Wall Street extends sell-off on fears of longer-term inflation wave</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">02:06PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/research/li-auto-stock-buy-now/?src=A00220" target="_blank">Is Li Auto Stock A Buy Or Sell After EV Maker's October Deliveries Double?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">01:52PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/electric-vehicle-company-valuations-indicate-185259277.html" target="_blank">Electric vehicle company valuations 'indicate they'll absolutely dominate this space,' strategist says</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">01:46PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/rivian-ipo-looms-large-tesla-110604253.html" target="_blank">Sparkling Rivian IPO Adds to Bubble Talk in EV Space: Tech Watch</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">01:46PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/rivian-does-tick-lot-different-184617985.html" target="_blank">What Rivian does is 'tick a lot of different boxes': Autoblog EIC</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">01:46PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/bulls-creep-back-tesla-options-184609034.html" target="_blank">Bulls creep back in to Tesla options after stock selloff</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">01:43PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/rivian-jumps-trading-debut-valued-184301911.html" target="_blank">Rivian jumps in trading debut, valued at $93 billion</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">01:35PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/research/gm-stock-buy-now/?src=A00220" target="_blank">GM Stock A Buy? General Motors Claims Self-Driving Lead, Cruises Into Buy Range</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">01:32PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/news/rivian-stock-to-buy-rivian-ipo/?src=A00220" target="_blank">Is Rivian Stock A Buy? RIVN IPO Raises $11.9 Billion, Soars In Debut</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">01:17PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/factbox-five-ways-newly-public-181726661.html" target="_blank">Factbox-Five ways newly public EV startup Rivian compares with Tesla</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">12:52PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/us-stocks-wall-st-falls-175201149.html" target="_blank">US STOCKS-Wall St falls as hot consumer prices data fuels inflation worries</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">12:46PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/news/lucid-stock-poised-double-lcid-shares-edge-tesla-analyst-says/?src=A00220" target="_blank">Lucid Could Be Poised To Double Because It Shares This Edge With Tesla, Analyst Says</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">12:09PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/bmw-boss-takes-aim-teslas-170901503.html" target="_blank">BMW boss takes aim at Tesla's quality and reliability</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> The Telegraph</span></div></div></td></tr>
# <tr><td align="right" width="130">11:22AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/don-t-elon-musk-expensive-162200678.html" target="_blank">Dont make Elon Musks expensive stock options tax mistake</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Fortune</span></div></div></td></tr>
# <tr><td align="right" width="130">11:10AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/buy-dip-tesla-etfs-161004156.html" target="_blank">Should You Buy the Dip in Tesla With These ETFs?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
# <tr><td align="right" width="130">11:01AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/nio-stock-earnings-51636498194?siteid=yhoof2" target="_blank">NIOs Earnings Were Fine, but Not Guidance. Its Stock Is OK. What a Surprise.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">10:45AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2021/11/10/why-teslas-stock-roared-back-to-life-today/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Tesla's Stock Roared Back to Life Today</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">10:42AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/rivian-indicated-open-120-share-154214177.html" target="_blank">Rivian indicated to open at $120 a share in IPO</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">10:37AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investopedia.com/tesla-rout-continues-5209066?utm_campaign=quote-yahoo&amp;utm_source=yahoo&amp;utm_medium=referral" target="_blank">Tesla (TSLA) Rout Continues</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investopedia</span></div></div></td></tr>
# <tr><td align="right" width="130">10:15AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.bizjournals.com/sanjose/news/2021/11/10/tesla-rival-rivian-raises-nearly-12b-in-ipo.html?ana=yahoo" target="_blank">Amazon-backed Tesla rival Rivian raises nearly $12B in blockbuster IPO</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> American City Business Journals</span></div></div></td></tr>
# <tr><td align="right" width="130">09:54AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/retail-traders-flock-ev-stocks-145415596.html" target="_blank">Retail Traders Flock to EV Stocks With an Eye on U.S. Carmakers</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">09:30AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/rivian-ceo-sees-annual-production-143000120.html" target="_blank">Rivian CEO sees annual production capacity of at least 1 mln vehicles before 2030</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">08:47AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/tesla-shares-steady-two-day-134737841.html" target="_blank">Tesla selloff puts at risk its $1 trillion club membership</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">08:27AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/tesla-stock-price-elon-musk-sale-51636496151?siteid=yhoof2" target="_blank">Tesla Keeps Falling. Why Elon Musks Stock Sale Could Be Good News.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">08:24AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/tesla-apple-amazon-tech-stocks-expensive-51636494599?siteid=yhoof2" target="_blank">Microsoft, Apple, and Other Tech Stocks Have Soared. They Arent That Expensive.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">08:04AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-market-rally-pauses-as-tesla-dives-upstart-earnings-movers-rivian-ipo/?src=A00220" target="_blank">Dow Jones Futures: A Bad Sign For Growth, Market Rally; Rivian IPO Delivers After Tesla Dives</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">07:20AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2021/11/10/hot-growth-stock-still-buy-after-big-gain-lucid/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">This Hot Growth Stock Is Still a Buy After Enormous Gains</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">06:36AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/things-to-know-today-51636537840?siteid=yhoof2" target="_blank">Tesla Didnt Rain on the Parade for Rivians Supercharged IPO</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">03:17AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/elon-musk-fortune-plunges-50bn-081755179.html" target="_blank">Elon Musks fortune plunges by $50bn in two days after controversial Tesla Twitter poll</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> The Independent</span></div></div></td></tr>
# <tr><td align="right" width="130">02:52AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.thestreet.com/markets/tesla-rivian-poshmark-dow-futures-dip-ahead-of-inflation-data?puc=yahoo&amp;cm_ven=YAHOO" target="_blank">Tesla, Rivian, Poshmark, Coinbase In Focus; Dow Futures Dip Ahead of Inflation Data - Stock Market Live</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> TheStreet.com</span></div></div></td></tr>
# <tr><td align="right" width="130">02:30AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.thestreet.com/markets/tesla-stock-extends-slide-clipping-200-million-from-market-cap?puc=yahoo&amp;cm_ven=YAHOO" target="_blank">Tesla Stock Extends Slide, Clipping $200 Million From Market Value, As Investors Eye Musk Share Sale</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> TheStreet.com</span></div></div></td></tr>
# <tr><td align="right" style="white-space:nowrap" width="130">Nov-09-21 10:00PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2021/11/09/adt-to-acquire-sunpro-solar-for-roughly-825-millio/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">ADT To Acquire Sunpro Solar for Roughly $825 Million</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span> <span class="body-table-news-loss">-11.99%</span></div></div></td></tr>
# <tr><td align="right" width="130">06:25PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/hertz-shares-fall-after-re-ipo-equity-offering-51636481632?siteid=yhoof2" target="_blank">Hertz Had a Rough Day After Re-IPO Equity Offering</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">05:58PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.wsj.com/articles/own-tesla-stock-be-like-elon-musk-and-sell-11636462480?mod=itp_wsj" target="_blank">Own Tesla Stock? Be Like Elon Musk and Sell</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> The Wall Street Journal</span></div></div></td></tr>
# <tr><td align="right" width="130">05:51PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/nio-stock-earnings-guidance-51636498194?siteid=yhoof2" target="_blank">NIOs Earnings Were Fine, but Guidance Wasnt. Wednesday Is a Wild Card for the Stock.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">05:41PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/elon-musk-loses-50-billion-224130205.html" target="_blank">Elon Musk Loses $50 Billion in Two Days in Record Wealth Plunge</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">05:16PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/tesla-stock-elon-musk-51636496151?siteid=yhoof2" target="_blank">Tesla Stock Keeps Tanking. How an Elon Musk Sale Could Be Good News.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">05:01PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/why-some-financial-advisers-say-its-worth-weighing-end-of-year-stock-sales-just-like-the-tesla-ceo-is-doing-and-ikea-expands-its-buy-back-and-resell-program-for-used-furniture-to-all-u-s-stores-11636495263?siteid=yhoof2" target="_blank">Why some financial advisers say its worth weighing end-of-year stock sales  just like the Tesla CEO is doing and IKEA expands its buy back and resell program for used furniture to all U.S. stores</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" width="130">04:50PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/some-big-tech-stocks-have-gone-bonkers-theyre-not-that-expensive-51636494599?siteid=yhoof2" target="_blank">Some Big Tech Stocks Have Gone Bonkers. Theyre Not That Expensive.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">04:24PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/tesla-selloff-deepens-insider-report-160656521.html" target="_blank">Tesla Erases $199 Billion in Worst Two-Day Rout in 14 Months</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">04:15PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/market-trend/stock-market-today/dow-jones-dips-tesla-stock-selloff-intensifies-after-mooted-elon-musk-sale-bitcoin-gains-ahead-of-coinbase-earnings/?src=A00220" target="_blank">Dow Jones Dips; Tesla Sell-Off Intensifies After Mooted Elon Musk Sale; Bitcoin Gains Ahead Of Coinbase Earnings</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">04:11PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/sp-500-skids-lower-tuesday-and-misses-longest-streak-of-record-closes-in-66-years-as-teslas-stock-tumbles-12-2021-11-09?siteid=yhoof2" target="_blank">S&amp;P 500 skids lower Tuesday and misses longest streak of record closes in 66 years as Tesla's stock tumbles 12%</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" width="130">04:01PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/us-stocks-wall-street-ends-210109488.html" target="_blank">US STOCKS-Wall Street ends down, snapping run of record highs as inflation worries weigh</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">03:39PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/ceo-microstrategy-just-predicted-bitcoin-203900577.html" target="_blank">The CEO of MicroStrategy just predicted that Bitcoin is 'going up forever'  here are 3 other companies with plenty of crypto on the balance sheet</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MoneyWise</span></div></div></td></tr>
# <tr><td align="right" width="130">03:11PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/news/best-ev-stocks-buy-now-electric-cars/?src=A00220" target="_blank">These Are The Best EV Stocks To Buy And Watch Now</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">02:23PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/us-stocks-wall-street-declines-192317296.html" target="_blank">REFILE-US STOCKS-Wall Street declines, ending a run of record highs</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">02:12PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/market-trend/stock-market-today/dow-jones-tesla-stock-paypal-slide-these-growth-stocks-pop/?src=A00220" target="_blank">Dow Jones, S&amp;P 500 Decline As Tech Stocks Lead Downside; Tesla Stock, PayPal Slide While These Growth Stocks Pop</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">02:09PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.bizjournals.com/baltimore/news/2021/11/09/t-rowe-price-stake-in-rivan-worth-10-billion.html?ana=yahoo" target="_blank">Rivian IPO could be one of T. Rowe Price's biggest ever</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> American City Business Journals</span></div></div></td></tr>
# <tr><td align="right" width="130">01:22PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/hertz-ceo-on-tesla-deal-we-want-to-lead-the-adoption-of-electric-vehicles-182234573.html" target="_blank">Hertz CEO on Tesla deal: We want to lead the adoption of electric vehicles</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance</span></div></div></td></tr>
# <tr><td align="right" width="130">01:15PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/live-your-life-like-elon-musk-why-some-financial-advisers-say-its-worth-weighing-end-of-year-stock-sales-just-like-the-tesla-ceo-is-doing-11636481733?siteid=yhoof2" target="_blank">Live your life like Elon Musk: Why some financial advisers say its worth weighing end-of-year stock sales  just like the Tesla CEO is doing</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" width="130">12:52PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/market-check-stocks-dip-intraday-175200227.html" target="_blank">Market check: Stocks dip in intraday trading after record run</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">12:51PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/market-check-stocks-dip-intraday-175153802.html" target="_blank">Market check: Stocks dip in intraday trading after record run</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">12:47PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/elon-musk-brother-sold-109-160458311.html" target="_blank">Elon Musks Brother Sold $109 Million in Tesla Stock Ahead of Poll</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">12:44PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/tesla-stock-falls-more-than-9-extends-losses-to-third-session-2021-11-09?siteid=yhoof2" target="_blank">Tesla stock falls more than 9%, extends losses to third session</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" width="130">12:27PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/fed-policy-dovishness-going-win-172735474.html" target="_blank">Fed policy: Dovishness is going to win the day, strategist says</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">12:26PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/market-trend/stock-market-today/dow-jones-drops-three-stocks-weigh-rivian-ipo-on-tap-tesla-skids/?src=A00220" target="_blank">Dow Drops 250 Points As 3 Stocks Weigh; Rivian IPO On Tap As Tesla Skids</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">11:56AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/electric-truck-maker-rivian-seeking-165618205.html" target="_blank">Electric truck maker Rivian seeking up to $10 billion in IPO</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">11:22AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://qz.com/2086846/rivians-ipo-success-hinges-on-a-major-amazon-purchase/?utm_source=YPL" target="_blank">Amazon is EV startup Rivians biggest investorand its most important customer</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Quartz</span></div></div></td></tr>
# <tr><td align="right" width="130">11:21AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2021/11/09/why-tesla-stock-fell-further-on-tuesday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Tesla Stock Fell Further on Tuesday</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">10:48AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/hertz-ceo-mark-fields-whats-154802680.html" target="_blank">Hertz CEO Mark Fields on what's next, Tesla deal: 'This is a transformation story'</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">10:37AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/tesla-shanghai-factories-evs-51636472015?siteid=yhoof2" target="_blank">Tesla Needs More Factories to  Meet Its Growth Goals. Shanghai Could Get the Next One.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">10:12AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/bitcoin-climbs-record-high-exceeding-232052485.html" target="_blank">Bitcoin, Ether Hit Records Amid Broad Rally in Cryptocurrencies</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">09:57AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-fall-as-bitcoin-hits-record-high-key-earnings-movers-include-roblox/?src=A00220" target="_blank">Dow Jones Falls As Bitcoin Hits Record High; Palantir, PayPal Dive On Earnings</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">08:56AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/us-stocks-wall-street-set-135609824.html" target="_blank">US STOCKS-Wall Street set for subdued open, GE surges on split</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">08:37AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/elon-musk-sell-tesla-stock-51636412339?siteid=yhoof2" target="_blank">Whats Really Behind Elon Musks Possible Tesla Stock Sale</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">08:15AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/tesla-stock-elon-musk-51636412339?siteid=yhoof2" target="_blank">Whats Really Behind Elon Musks Possible Tesla Stock Sale</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">08:10AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/10-best-stocks-2021-131045528.html" target="_blank">10 Best Stocks of 2021</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Insider Monkey</span></div></div></td></tr>
# <tr><td align="right" width="130">08:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/etfs-and-funds/sectors/sp500-how-investors-just-made-easy-1-point-3-trillion-dollars-in-seven-days/?src=A00220" target="_blank">How Investors Just Made An Easy $1.3 Trillion In 7 Days</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">07:55AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/ev-roundup-tsla-ceo-musks-125512265.html" target="_blank">EV Roundup: TSLA CEO Musk's Mysterious Tweets Make the Most Noise</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
# <tr><td align="right" width="130">07:31AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/4-top-ranked-efficient-stocks-123112627.html" target="_blank">4 Top-Ranked Efficient Stocks to Enrich Your Portfolio</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
# </table>

# %%
'''We have grabbed the table that contains the headlines from each stocks HTML file, 
   here we will try to understand how the data has been structured
   in the table before we parse the tables further
   We explore the headlines here
   
   Reading one single file of headlines '''
#taking headlines from tsla dated october 2021 in html file
tsla = htmlTables['hdb_oct2021.html']
# Get all the table rows tagged in HTML with <tr> tablerow into tesla_tr
tsla_tr = tsla.findAll('tr')

print("Number of headlines on this day :", len(tsla_tr))

#exploring data for better understanding
#For each row
for i, table_row in enumerate(tsla_tr):
    # Reading text of the element 'a' into linkText as a has link texts in html
    linkText = table_row.a.get_text()
    # Reading the text of the element 'td' into dataText where td is table data cells
    dataText = table_row.td.get_text()
    # Print the count of the number of files
    print(f"File number {i+1}:")
    # Print the contents of linkText and dataText
    print(linkText)
    print(dataText)
    # exiting the loop after first 10 files as this is for exploring only
    if i == 9:
        break
# Out:
# Number of headlines on this day : 100
# File number 1:
# Top Indian Mortgage Lenders Profit Rises on Dividend Income
# Nov-01-21 06:17AM
# File number 2:
# HDFC Bank Limited (HDB): Hedge Funds Are Snapping Up
# Oct-12-21 07:16PM
# File number 3:
# Cathie Woods Fintech ETF Sells HDFC Bank First Time Since May
# Sep-02-21 11:30PM
# File number 4:
# India's HDFC Bank aims to reclaim credit card market share in coming quarters
# Aug-23-21 05:21AM
# File number 5:
# Indian shares snap multi-day rally as banks, metal stocks slip
# Aug-18-21 12:20AM
# File number 6:
# India ETFs Hit Record High Ahead of Central Bank Meeting
# Aug-04-21 09:42AM
# File number 7:
# Is HDFC Bank Limited (HDB) A Smart Long-Term Buy?
# Aug-02-21 12:54PM
# File number 8:
# TD vs. HDB: Which Stock Is the Better Value Option?
# Jul-30-21 11:40AM
# File number 9:
# HDFC Bank Limited 20-F Available Online
# Jul-28-21 10:00AM
# File number 10:
# HDFC Bank Limited (HDB) Q1 2022 Earnings Call Transcript
# Jul-25-21 07:37AM

# %%
'''
creating empty list for holding parsed news
and iterating through it
'''
parsedNews = []
#earlier we did this for a single file now doing for all
for fileName, newsTable in htmlTables.items():
    # Iterate through all tr tags in 'newsTable'
    for x in newsTable.findAll('tr'):
        # Read the text from the tr tag into text
        text = x.get_text() 
        
        # Split the text in the td tag into a list 
        #considering it may contain both time and date or only time
        dateScrape = x.td.text.split()
        # If the length of dateScrape is 1, load 'time' as the only element
        # If is not, load 'date' as the 1st element and 'time' as the second
        if len(dateScrape) == 1:
            time = dateScrape[0]
        else:
            date = dateScrape[0]
            time = dateScrape[1]
        #ticker is short form name upto first '_' in filename we are considering for stock market information or news reports.
        # Extract the ticker from the file name  
        ticker = fileName.split("_")[0]
        # Appending ticker, date, time and headline as a list to the 'parsed_news' list
        parsedNews.append([ticker, date, time, x.a.text])

# %%
print(parsedNews)
# Out:
# [['fb', 'Nov-10-21', '09:32PM', 'SHAREHOLDER ALERT: Levi & Korsinsky, LLP Notifies Shareholders of Meta Platforms, Inc. f.k.a. Facebook, Inc. of a Class Action Lawsuit and a Lead Plaintiff Deadline of December 27, 2021 - FB'], ['fb', 'Nov-10-21', '09:07PM', 'China Crackdown Hammers Growth at National Champion Tencent'], ['fb', 'Nov-10-21', '08:00PM', 'INVESTOR ALERT - Labaton Sucharow Notifies Meta Platforms, Inc. f/k/a Facebook, Inc. (NASDAQ:FB) Investors of Securities Class Action'], ['fb', 'Nov-10-21', '07:01PM', "Solana  why Ethereum's lesser known rival is steadily rising"], ['fb', 'Nov-10-21', '07:01PM', 'WhatsApp launches scam awareness campaign'], ['fb', 'Nov-10-21', '05:01PM', 'Facebook under fire for supreme court failings'], ['fb', 'Nov-10-21', '04:03PM', 'UPDATE 2-Cuba says United States, Facebook helping to foment Nov. 15 protests'], ['fb', 'Nov-10-21', '03:59PM', 'Why AMD Stock Fell 7% Today'], ['fb', 'Nov-10-21', '03:55PM', 'SHAREHOLDER ALERT: FB HMLP CEI: The Law Offices of Vincent Wong Reminds Investors of Important Class Action Deadlines'], ['fb', 'Nov-10-21', '03:36PM', 'U.S., China Surprise Summit With Joint Commitment: COP26 Update'], ['fb', 'Nov-10-21', '03:12PM', 'SHAREHOLDER ACTION ALERT: The Schall Law Firm Reminds Investors of a Class Action Lawsuit Against Meta Platforms, Inc. f/k/a Facebook, Inc. and Encourages Investors with Losses in Excess of $100,000 to Contact the Firm'], ['fb', 'Nov-10-21', '03:11PM', 'Kraken CEO on what metaverse means for NFTs, gaming, and crypto'], ['fb', 'Nov-10-21', '03:00PM', 'The Klein Law Firm Reminds Investors of Class Actions on Behalf of Shareholders of FB, ONTF and SBTX'], ['fb', 'Nov-10-21', '02:26PM', 'Nvidia GM of embedded and edge computing details latest advancements in robotics and virtual worlds'], ['fb', 'Nov-10-21', '01:45PM', "Expensify CEO: 'Instagram has connected a billion people through photography, we can do it through money'"], ['fb', 'Nov-10-21', '01:16PM', 'UPDATE 1-Cuba threatens to sue Facebook, alleging it aided dissidents'], ['fb', 'Nov-10-21', '01:15PM', 'IMPORTANT REMINDER: FACEBOOK, INC. (NASDAQ: FB) SHAREHOLDER CLASS ACTION DEADLINE- Bernstein Liebhard LLP Reminds Investors of the Deadline to File a Lead Plaintiff Motion in a Securities Class Action Lawsuit Against Facebook, Inc.'], ['fb', 'Nov-10-21', '12:45PM', 'The Klein Law Firm Reminds Investors of Class Actions on Behalf of Shareholders of HNST, FB and HMLP'], ['fb', 'Nov-10-21', '12:00PM', 'FB ALERT - Nationally Ranked Shareholder Rights Firm Labaton Sucharow Notifies Meta Platforms, Inc. f/k/a Facebook, Inc. (NASDAQ:FB) Investors of Securities Class Action'], ['fb', 'Nov-10-21', '11:45AM', 'CLASS ACTION UPDATE for FB, CEI and ONTF: Levi & Korsinsky, LLP Reminds Investors of Class Actions on Behalf of Shareholders'], ['fb', 'Nov-10-21', '11:15AM', 'FIRST FILING AND TOP INVESTOR RIGHTS LAW FIRM, ROSEN, Encourages Meta Platforms, Inc. f/k/a Facebook, Inc. Investors with Losses in Excess of $100K to Secure Counsel Before Important Deadline in Class Action  FB'], ['fb', 'Nov-10-21', '11:00AM', 'TME, FB & HMLP - Class Action Alerts: Bronstein, Gewirtz & Grossman, LLC'], ['fb', 'Nov-10-21', '10:30AM', "These New Products Have AMD's Stock Price Soaring"], ['fb', 'Nov-10-21', '10:15AM', 'Amazon-backed Tesla rival Rivian raises nearly $12B in blockbuster IPO'], ['fb', 'Nov-10-21', '10:08AM', "Facebook's work app Workplace to integrate with Microsoft Teams"], ['fb', 'Nov-10-21', '10:00AM', "Facebook's work app Workplace to integrate with Microsoft Teams"], ['fb', 'Nov-10-21', '09:40AM', 'The Gross Law Firm Announces Class Actions on Behalf of Shareholders of FB, HMLP and ONTF'], ['fb', 'Nov-10-21', '08:40AM', 'INVESTOR ACTION NOTICE: The Schall Law Firm Reminds Investors of a Class Action Lawsuit Against Meta Platforms, Inc. f/k/a Facebook, Inc. and Encourages Investors with Losses in Excess of $100,000 to Contact the Firm'], ['fb', 'Nov-10-21', '05:07AM', 'Facebook reportedly said no problem ...

# %%
# most used library for NLP
import nltk
#nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# SentimentIntensityAnalyzer is used to determine intensity of word, positivity or negativity etc.
# most reliable as human raters have given intensity scores to each word 
# amazon mechanical turk (platform used by raters) using which this library is made

# %%
# words and values 
wordIntensityScores = {
    'crushes': 8,
    'beats': 5,
    'misses': -5,
    'trouble': -10,
    'falls': -100,
    'bullish': 7,
    'bearish':-7,
    'short':-10, # you sell 
    'sell':-7,
    'breakout':4,
    'crushed': 8,
    'dip':-3,
    'crahs':-10,
    'tanks':-4,
    'high':3,
    'low':-3,
    'rising':3,
    'down':-2,
}

# Instantiate the sentiment intensity analyzer with the existing lexicon
vader = SentimentIntensityAnalyzer()
# print(vader.lexicon)

# Updating the lexicon with the above values for specifically stock
vader.lexicon.update(wordIntensityScores)

# %%
import speech_recognition as sr
from tkinter import *
root = Tk()
root.title("News Headline Stock Sentiment Analysis")
root.geometry("500x100")
root.configure(bg ="#031163")
r3 = sr.Recognizer()

with sr.Microphone() as source:
    r3.adjust_for_ambient_noise(source)
    print("Speak Now")
    #for example say stocks are falling
    audio = r3.listen(source)
    
    try:
        text = r3.recognize_google(audio)
        print("You said : " + text)
        score = vader.polarity_scores(text)
        print(score)
        ss = float(vader.polarity_scores(text)['compound'])
        print(ss)
        if ss > 0.0:
            title_label = Label(root, text = "Depicts positive stock sentiment", font = ("Helvetica",18), fg= "#070e57", bg = "#7ddae8")
            title_label.grid(row=0,column=0,columnspan=3,pady="20")
            print("\nDepicts positive stock sentiment\n")
        elif ss < 0.0:
            title_label1 = Label(root, text = "Depicts negative stock sentiment", font = ("Helvetica",18), fg= "#070e57", bg = "#7ddae8")
            title_label1.grid(row=0,column=0,columnspan=3,pady="20")
            print("\nDepicts negative stock sentiment\n")
        else:
            title_label2 = Label(root, text = "Depicts neutral stock sentiment", font = ("Helvetica",18), fg= "#070e57", bg = "#7ddae8")
            title_label2.grid(row=0,column=0,columnspan=3,pady="20")
            print("\nDepicts neutral sentiment\n")
        
    except sr.UnknownValueError:
        print("Could not understand")
    except sr.RequestError as e:
        print("Could not request results")
root.mainloop()
# Out:
# Speak Now
# You said : the market stocks are falling down
# {'neg': 0.535, 'neu': 0.465, 'pos': 0.0, 'compound': -0.5574}
# -0.5574
#
# Depicts negative stock sentiment

# %%
# using audio files
import speech_recognition as sr
from tkinter import *
root = Tk()
root.title("News Headline Stock Sentiment Analysis")
root.geometry("500x100")
root.configure(bg ="#031163")


financialNews1 = ("Ai_audio2.wav")

r = sr.Recognizer()
  
with sr.AudioFile(financialNews1) as source:
    #reads the audio file. Here we use record instead of listening
    audio = r.record(source)  
  
try:
    audioText = r.recognize_google(audio)
    print("The audio file contains: " + audioText)
    score = vader.polarity_scores(audioText)
    print(score)
    ss = vader.polarity_scores(audioText)['compound']
    if ss > 0.0:
        title_label = Label(root, text = "Depicts positive stock sentiment", font = ("Helvetica",18), fg= "#070e57", bg = "#7ddae8")
        title_label.grid(row=0,column=0,columnspan=3,pady="20")
        print("\nDepicts positive stock sentiment\n")
    elif ss < 0.0:
        title_label1 = Label(root, text = "Depicts negative stock sentiment", font = ("Helvetica",18), fg= "#070e57", bg = "#7ddae8")
        title_label1.grid(row=0,column=0,columnspan=3,pady="20")
        print("\nDepicts negative stock sentiment\n")
    else:
        title_label2 = Label(root, text = "Depicts neutral stock sentiment", font = ("Helvetica",18), fg= "#070e57", bg = "#7ddae8")
        title_label2.grid(row=0,column=0,columnspan=3,pady="20")
        print("\nDepicts neutral sentiment\n")
  
except sr.UnknownValueError:
    print("Could not understand audio")
  
except sr.RequestError as e:
    print("Could not request results from Google Speech")
root.mainloop()
# Out:
# The audio file contains: Sensex tanks over 500 points below 60,000 Nifty gives up 17850 on futures and options expiry date
# {'neg': 0.22, 'neu': 0.661, 'pos': 0.119, 'compound': -0.5106}
#
# Depicts negative stock sentiment

# %%
import pandas as pd

# Using these as column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the list of lists into a DataFrame
# as earlier for every news headline there was a single list with many lists in it
scoredNews = pd.DataFrame(parsedNews, columns = columns)

# Iterate through the headlines and get the polarity(intensity) scores
# head is each instance of headline
scores = [vader.polarity_scores(head) for head in scoredNews.headline]

# polarity scores returns in dictionary form
# Converting the list of dictionaries into a DataFrame
scoresDF = pd.DataFrame(scores)

# Join the DataFrames of headlines with polarity scores 
scoredNews = scoredNews.join(scoresDF)

# Converting the date column from string to datetime
scoredNews['date'] = pd.to_datetime(scoredNews.date).dt.date

# %%
print(scores)
# scores are in terms negative, neutral, positive, compound
# compound score is sum of positive, negative & neutral scores which is then normalized between -1 and +1
# compound score closer to +1 indicates positivity of text, in this case stock headlines
# Out:
# [{'neg': 0.064, 'neu': 0.838, 'pos': 0.098, 'compound': 0.2577}, {'neg': 0.0, 'neu': 0.48, 'pos': 0.52, 'compound': 0.7579}, {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.6289}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.481, 'neu': 0.519, 'pos': 0.0, 'compound': -0.5719}, {'neg': 0.424, 'neu': 0.303, 'pos': 0.273, 'compound': -0.25}, {'neg': 0.119, 'neu': 0.566, 'pos': 0.314, 'compound': 0.4767}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.772, 'pos': 0.228, 'compound': 0.5766}, {'neg': 0.0, 'neu': 0.598, 'pos': 0.402, 'compound': 0.5719}, {'neg': 0.117, 'neu': 0.735, 'pos': 0.148, 'compound': 0.3034}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.224, 'neu': 0.776, 'pos': 0.0, 'compound': -0.3818}, {'neg': 0.055, 'neu': 0.808, 'pos': 0.137, 'compound': 0.4278}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.6289}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.067, 'neu': 0.694, 'pos': 0.239, 'compound': 0.7125}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.5994}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.171, 'neu': 0.829, 'pos': 0.0, 'compound': -0.4767}, {'neg': 0.123, 'neu': 0.8, 'pos': 0.077, 'compound': -0.1779}, {'neg': 0.381, 'neu': 0.619, 'pos': 0.0, 'compound': -0.8225}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.6369}, {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.6369}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.175, 'neu': 0.825, 'pos': 0.0, 'compound': -0.3254}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.123, 'neu': 0.8, 'pos': 0.077, 'compound': -0.1779}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.772, 'pos': 0.228, 'compound': 0.5766}, {'neg': 0.117, 'neu': 0.735, 'pos': 0.148, 'compound': 0.3034}, {'neg': 0.425, 'neu': 0.575, 'pos': 0.0, 'compound': -0.8126}, {'neg': 0.22, 'neu': 0.655, 'pos': 0.125, 'compound': -0.3818}, {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.6289}, {'neg': 0.135, 'neu': 0.865, 'pos': 0.0, 'compound': -0.1027}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.659, 'pos': 0.341, 'compound': 0.6908}, {'neg': 0.175, 'neu': 0.554, 'pos': 0.271, 'compound': 0.2577}, {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'compound': 0.296}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.3182}, {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.3182}, {'neg': 0.153, 'neu': 0.584, 'pos': 0.263, 'compound': 0.3612}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.333, 'neu': 0.667, 'pos': 0.0, 'compound': -0.4588}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.056, 'neu': 0.803, 'pos': 0.141, 'compound': 0.4278}, {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.6124}, {'neg': 0.86, 'neu': 0.119, 'pos': 0.02, 'compound': -0.9992}, {'neg': 0.0, 'neu': 0.678, 'pos': 0.322, 'compound': 0.5859}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.175, 'neu': 0.825, 'pos': 0.0, 'compound': -0.3254}, {'neg': 0.0, 'neu': 0.877, 'pos': 0.123, 'compound': 0.2732}, {'neg':  ...

# %%
print(scoresDF.head(5)) #returns number of instances in .head()
# Out:
#      neg    neu    pos  compound
# 0  0.064  0.838  0.098    0.2577
# 1  0.000  0.480  0.520    0.7579
# 2  0.000  0.745  0.255    0.6289
# 3  0.000  1.000  0.000    0.0000
# 4  0.481  0.519  0.000   -0.5719

# %%
print(scoredNews)
# Out:
#     ticker        date     time  \
# 0       fb  2021-11-10  09:32PM
# 1       fb  2021-11-10  09:07PM
# 2       fb  2021-11-10  08:00PM
# 3       fb  2021-11-10  07:01PM
# 4       fb  2021-11-10  07:01PM
# ..     ...         ...      ...
# 395   tsla  2021-11-09  08:15AM
# 396   tsla  2021-11-09  08:10AM
# 397   tsla  2021-11-09  08:00AM
# 398   tsla  2021-11-09  07:55AM
# 399   tsla  2021-11-09  07:31AM
#
#                                               headline    neg    neu    pos  \
# 0    SHAREHOLDER ALERT: Levi & Korsinsky, LLP Notif...  0.064  0.838  0.098
# 1    China Crackdown Hammers Growth at National Cha...  0.000  0.480  0.520
# 2    INVESTOR ALERT - Labaton Sucharow Notifies Met...  0.000  0.745  0.255
# 3    Solana  why Ethereum's lesser known rival is s...  0.000  1.000  0.000
# 4            WhatsApp launches scam awareness campaign  0.481  0.519  0.000
# ..                                                 ...    ...    ...    ...
# 395  Whats Really Behind Elon Musks Possible Tesla ...  0.000  1.000  0.000
# 396                             10 Best Stocks of 2021  0.000  0.488  0.512
# 397  How Investors Just Made An Easy $1.3 Trillion ...  0.000  0.756  0.244
# 398  EV Roundup: TSLA CEO Musk's Mysterious Tweets ...  0.000  1.000  0.000
# 399  4 Top-Ranked Efficient Stocks to Enrich Your P...  0.000  0.682  0.318
#
#      compound
# 0      0.2577
# 1      0.7579
# 2      0.6289
# 3      0.0000
# 4     -0.5719
# ..        ...
# 395    0.0000
# 396    0.6369
# 397    0.4404
# 398    0.0000
# 399    0.4215
#
# [400 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
plt.style.use("classic")
# %matplotlib inline

# Group by date and ticker columns from scored_news and calculate the mean
mean_c = scoredNews.groupby(['date', 'ticker']).mean();

# Unstack the column ticker
mean_c = mean_c.unstack('ticker');

# Get the cross-section of compound in the 'columns' axis
mean_c = mean_c.xs('compound', axis='columns');

# Plot a bar chart with pandas
mean_c.plot.bar(figsize = (25, 10), width = 1.75);
# stock sentiments date wise of fb tsla hdb and infy

# %%
# Count the number of headlines in scoredNews 
numNewsBefore = scoredNews.headline.count()

# Dropping duplicates based on ticker and headline
scoredNewsClean = scoredNews.drop_duplicates(subset= ['headline', 'ticker'])

# Counting number of headlines after dropping duplicates
numNewsAfter = scoredNewsClean.headline.count()

# Printing before and after numbers to get an idea of how we did 
print(f"Before we had {numNewsBefore} headlines, now we have {numNewsAfter}")
print("Number of dropped headlines are", numNewsBefore-numNewsAfter)
# Out:
# Before we had 400 headlines, now we have 355
# Number of dropped headlines are 45

# %%
# Setting the index to ticker and date
singleDay = scoredNewsClean.set_index(['ticker', 'date'])
#print(single_day.head(1))
# Cross-section the fb row
singleDay = singleDay.xs('tsla')
#print(single_day)
# Selecting by locating the 9th November 2021
singleDay = singleDay.loc[pd.Timestamp('2021-11-09')]

#Converting the datetime string to just the time
singleDay['time'] = pd.to_datetime(singleDay['time']).dt.time

# Set the index to time 
singleDay = singleDay.set_index('time')

# Sort it
singleDay = singleDay.sort_index()
# Out:
# c:\users\anjali ajay dofe\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py:3361: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   return self._engine.get_loc(casted_key)

# %%
TITLE = "Negative, neutral, and positive sentiment for TSLA on 2021-11-09"

# Drop the columns that aren't useful for the plot
plotDay = singleDay.drop(['compound', 'headline'], 1)

# Change the column names to 'negative', 'positive', and 'neutral'
plotDay.columns = ['negative', 'neutral', 'positive']

# Plot a stacked bar chart
plotDay.plot.bar(stacked=True, figsize=(12, 8), title=TITLE).legend(bbox_to_anchor=(1.2, 0.5))
plt.ylabel('scores');
# Out:
# <ipython-input-28-af3ab6e9ed40>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   plotDay = singleDay.drop(['compound', 'headline'], 1)

# %%
# Setting the index to ticker and date
singleDay2 = scoredNewsClean.set_index(['ticker', 'date'])
#print(single_day.head(1))
# Cross-section the fb row
singleDay2 = singleDay2.xs('infy')
#print(single_day)
# Selecting by locating the 9th November 2021
singleDay2 = singleDay2.loc[pd.Timestamp('2021-10-13')]

#Converting the datetime string to just the time
singleDay2['time'] = pd.to_datetime(singleDay2['time']).dt.time

# Set the index to time 
singleDay2 = singleDay2.set_index('time')

# Sort it
singleDay2 = singleDay2.sort_index()

# %%
TITLE = "Negative, neutral, and positive sentiment for Infosys on 2021-10-13"

# Drop the columns that aren't useful for the plot
plotDay = singleDay2.drop(['compound', 'headline'], 1)

# Change the column names to 'negative', 'positive', and 'neutral'
plotDay.columns = ['negative', 'neutral', 'positive']

# Plot a stacked bar chart
plotDay.plot.bar(stacked=True, figsize=(10, 7), title=TITLE).legend(bbox_to_anchor=(1.2, 0.5))
plt.ylabel('scores');
# Out:
# <ipython-input-92-52b0e0403ff9>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   plotDay = singleDay2.drop(['compound', 'headline'], 1)
